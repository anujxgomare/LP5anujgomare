# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix

from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten

# %%
# Step 2: Load Fashion MNIST dataset

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()


# Step 3: Display dataset information

print("Training Data Shape:", X_train.shape)
print("Training Labels Shape:", y_train.shape)

print("Testing Data Shape:", X_test.shape)
print("Testing Labels Shape:", y_test.shape)
# Out:
# Training Data Shape: (60000, 28, 28)
# Training Labels Shape: (60000,)
# Testing Data Shape: (10000, 28, 28)
# Testing Labels Shape: (10000,)

# %%
# Step 4: Display one sample image

plt.imshow(X_train[0], cmap='gray')

plt.title("Sample Fashion Image")

plt.show()


# Print corresponding label

print("Label:", y_train[0])
# Out:
# Label: 9

# %%
# Step 5: Normalize image data

# Convert pixel values from 0-255 into 0-1

X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
# Step 6: Build Deep Neural Network model

model = Sequential()


# Flatten converts 28x28 image into 1D vector

model.add(Flatten(input_shape=(28, 28)))


# Hidden Layer 1

model.add(Dense(128, activation='relu'))


# Hidden Layer 2

model.add(Dense(64, activation='relu'))


# Output Layer

model.add(Dense(10, activation='softmax'))
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Step 7: Compile model

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Step 8: Train model

model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=128,
    validation_split=0.2
)
# Out:
# Epoch 1/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9265 - loss: 0.1959 - val_accuracy: 0.8982 - val_loss: 0.3037
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9297 - loss: 0.1875 - val_accuracy: 0.8923 - val_loss: 0.3115
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9302 - loss: 0.1839 - val_accuracy: 0.8960 - val_loss: 0.3039
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9315 - loss: 0.1807 - val_accuracy: 0.8955 - val_loss: 0.3191
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9334 - loss: 0.1757 - val_accuracy: 0.8930 - val_loss: 0.3245
# Epoch 6/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9351 - loss: 0.1724 - val_accuracy: 0.8936 - val_loss: 0.3203
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9357 - loss: 0.1697 - val_accuracy: 0.8954 - val_loss: 0.3128
# Epoch 8/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9376 - loss: 0.1641 - val_accuracy: 0.8932 - val_loss: 0.3359
# Epoch 9/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9394 - loss: 0.1616 - val_accuracy: 0.8923 - val_loss: 0.3397
# Epoch 10/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9402 - loss: 0.1580 - val_accuracy: 0.8911 - val_loss: 0.3375
# Epoch 11/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9428 - loss: 0.1521 - val_accuracy: 0.8940 - val_loss: 0.3367
# Epoch 12/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9448 - loss: 0.1452 - val_accuracy: 0.8954 - val_loss: 0.3493
# Epoch 13/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9462 - loss: 0.1446 - val_accuracy: 0.8949 - val_loss: 0.3570
# Epoch 14/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9473 - loss: 0.1384 - val_accuracy: 0.8950 - val_loss: 0.3603
# Epoch 15/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9492 - loss: 0.1352 - val_accuracy: 0.8862 - val_loss: 0.3817
# Epoch 16/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9508 - loss: 0.1313 - val_accuracy: 0.8941 - val_loss: 0.3647
# Epoch 17/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9529 - loss: 0.1255 - val_accuracy: 0.8940 - val_loss: 0.3899
# Epoch 18/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9532 - loss: 0.1230 - val_accuracy: 0.8954 - val_loss: 0.3677
# Epoch 19/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9538 - loss: 0.1214 - val_accuracy: 0.8909 - val_loss: 0.3905
# Epoch 20/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9572 - loss: 0.1138 - val_accuracy: 0.8847 - val_loss: 0.4195
# Epoch 21/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9557 - loss: 0.1161 - val_accuracy: 0.8968 - val_loss: 0.3862
# Epoch 22/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9592 - loss: 0.1094 - val_accuracy: 0.8952 - val_loss: 0.4072
# Epoch 23/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9595 - loss: 0.1062 - val_accuracy: 0.8928 - val_loss: 0.4310
# Epoch 24/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9608 - loss: 0.1044 - val_accuracy: 0.8910 - val_loss: 0.4271
# Epoch 25/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9623 - loss: 0.0997 - val_accuracy: 0.8927 - val_loss: 0.4229
# Epoch 26/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9632 - loss: 0.0967 - val_accuracy: 0.8925 - val_loss: 0.4449
# Epoch 27/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9628 - loss: 0.1009 - val_accuracy: 0.8892 - val_loss: 0.4694
# Epoch 28/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9636 - loss: 0.0965 - val_accuracy: 0.8932 - val_loss: 0.4335
# Epoch 29/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9657 - loss: 0.0915 - val_accuracy: 0.8911 - val_loss: 0.4285
# Epoch 30/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9660 - loss: 0.0879 - val_accuracy: 0.8923 - val_loss: 0.4695
# Epoch 31/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9682 - loss: 0.0856 - val_accuracy: 0.8906 - val_loss: 0.4915
# Epoch 32/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9684 - loss: 0.0830 - val_accuracy: 0.8892 - val_loss: 0.4719
# Epoch 33/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9680 - loss: 0.0854 - val_accuracy: 0.8924 - val_loss: 0.4741
# Epoch 34/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9714 - loss: 0.0783 - val_accuracy: 0.8945 - val_loss: 0.4898
# Epoch 35/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9718 - loss: 0.0758 - val_accuracy: 0.8857 - val_loss: 0.4995
# Epoch 36/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9699 - loss: 0.0780 - val_accuracy: 0.8952 - val_loss: 0.4877
# Epoch 37/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9718 - loss: 0.0751 - val_accuracy: 0.8916 - val_loss: 0.5114
# Epoch 38/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9707 - loss: 0.0770 - val_accuracy: 0.8924 - val_loss: 0.4838
# Epoch 39/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9750 - loss: 0.0683 - val_accuracy: 0.8900 - val_loss: 0.5399
# Epoch 40/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9740 - loss: 0.0699 - val_accuracy: 0.8925 - val_loss: 0.5334
# Epoch 41/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9743 - loss: 0.0664 - val_accuracy: 0.8928 - val_loss: 0.5127
# Epoch 42/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9751 - loss: 0.0673 - val_accuracy: 0.8968 - val_loss: 0.5188
# Epoch 43/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9759 - loss: 0.0635 - val_accuracy: 0.8917 - val_loss: 0.5379
# Epoch 44/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9758 - loss: 0.0642 - val_accuracy: 0.8889 - val_loss: 0.5435
# Epoch 45/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9772 - loss: 0.0605 - val_accuracy: 0.8878 - val_loss: 0.5536
# Epoch 46/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9761 - loss: 0.0617 - val_accuracy: 0.8932 - val_loss: 0.5551
# Epoch 47/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9780 - loss: 0.0605 - val_accuracy: 0.8878 - val_loss: 0.6232
# Epoch 48/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9794 - loss: 0.0571 - val_accuracy: 0.8907 - val_loss: 0.5572
# Epoch 49/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9800 - loss: 0.0533 - val_accuracy: 0.8924 - val_loss: 0.5451
# Epoch 50/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9786 - loss: 0.0569 - val_accuracy: 0.8901 - val_loss: 0.5843

# %%
# Step 9: Evaluate model

loss, accuracy = model.evaluate(X_test, y_test)

print("Loss:", loss)

print("Accuracy:", accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8865 - loss: 0.6479
# Loss: 0.647903323173523
# Accuracy: 0.8865000009536743

# %%
# Step 10: Predictions

predictions = model.predict(X_test)


# Convert probabilities into labels

predicted_labels = np.argmax(predictions, axis=1)


# Step 11: Confusion Matrix

cm = confusion_matrix(y_test, predicted_labels)

print("Confusion Matrix:")

print(cm)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Confusion Matrix:
# [[814   2  21  35   5   1 113   0   9   0]
#  [  1 982   4  10   0   0   2   0   1   0]
#  [ 19   1 787  12 118   0  60   0   3   0]
#  [ 13  10  11 890  37   1  30   0   8   0]
#  [  2   2  64  26 859   1  44   0   2   0]
#  [  3   0   1   0   0 970   0  12   4  10]
#  [109   1  80  35  77   0 689   0   9   0]
#  [  0   0   0   0   0  15   0 950   2  33]
#  [  9   0   3   2   6   4   4   4 968   0]
#  [  1   0   1   0   0  13   1  28   0 956]]

# %%
# Step 12: Print actual and predicted labels

for i in range(20):
    plt.imshow(X_test[i], cmap='gray')
    plt.title(f"X_Test Image {i}")
    plt.show()

    print("Actual Label:", y_test[i])

    print("Predicted Label:", predicted_labels[i])

    print("--------------------------------")
# Out:
# Actual Label: 9
# Predicted Label: 9
# --------------------------------
# Actual Label: 2
# Predicted Label: 2
# --------------------------------
# Actual Label: 1
# Predicted Label: 1
# --------------------------------
# Actual Label: 1
# Predicted Label: 1
# --------------------------------
# Actual Label: 6
# Predicted Label: 6
# --------------------------------
# Actual Label: 1
# Predicted Label: 1
# --------------------------------
# Actual Label: 4
# Predicted Label: 4
# --------------------------------
# Actual Label: 6
# Predicted Label: 6
# --------------------------------
# Actual Label: 5
# Predicted Label: 5
# --------------------------------
# Actual Label: 7
# Predicted Label: 7
# --------------------------------
# Actual Label: 4
# Predicted Label: 4
# --------------------------------
# Actual Label: 5
# Predicted Label: 5
# --------------------------------
# Actual Label: 7
# Predicted Label: 8
# --------------------------------
# Actual Label: 3
# Predicted Label: 3
# --------------------------------
# Actual Label: 4
# Predicted Label: 4
# --------------------------------
# Actual Label: 1
# Predicted Label: 1
# --------------------------------
# Actual Label: 2
# Predicted Label: 2
# --------------------------------
# Actual Label: 4
# Predicted Label: 2
# --------------------------------
# Actual Label: 8
# Predicted Label: 8
# --------------------------------
# Actual Label: 0
# Predicted Label: 0
# --------------------------------
